# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('G:/Ecommerce.csv' , encoding='ISO-8859-1')
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country  Unnamed: 8
# ...

# %%
df=pd.DataFrame(data)
print(df.shape)
df.head()
# Out:
# (541909, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country
# 0   29-Nov-16       2.55     17850.0  United Kingdom
# 1   29-Nov-16       3.39     17850.0  United Kingdom
# 2   29-Nov-16       2.75     17850.0  United Kingdom
# 3   29-Nov-16       3.39     17850.0  United Kingdom
# 4   29-Nov-16       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID Country
# 541904   07-Dec-17       0.85     12680.0  France
# 541905   07-Dec-17       2.10     12680.0  France
# 541906   07-Dec-17       4.15     12680.0  France
# 541907   07-Dec-17       4.15     12680.0  France
# 541908   07-Dec-17       4.95     12680.0  France

# %%
non_missing_values=df.count()
print(non_missing_values)
# Out:
# InvoiceNo      541909
# StockCode      541909
# Description    540455
# Quantity       541909
# InvoiceDate    541909
# UnitPrice      541909
# CustomerID     406829
# Country        541909
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#        InvoiceNo StockCode                         Description       Quantity  \
# count     541909    541909                              540455  541909.000000
# unique     25900      4070                                4223            NaN
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq        1114      2313                                2369            NaN
# mean         NaN       NaN                                 NaN       9.552250
# std          NaN       NaN                                 NaN     218.081158
# min          NaN       NaN                                 NaN  -80995.000000
# 25%          NaN       NaN                                 NaN       1.000000
# 50%          NaN       NaN                                 NaN       3.000000
# 75%          NaN       NaN                                 NaN      10.000000
# max          NaN       NaN                                 NaN   80995.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
df.count()
# Out:
# InvoiceNo      536640
# StockCode      536640
# Description    535186
# Quantity       536640
# InvoiceDate    536640
# UnitPrice      536640
# CustomerID     401603
# Country        536640
# dtype: int64

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
#Checking the negative values in the quantites column
negative_quantity = df[df['Quantity'] < 0]
print(negative_quantity)
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#converting to absolute value
df['Quantity']=df['Quantity'].abs()

# %%
negative_quantity = df[df['Quantity'] < 0]
print(negative_quantity)
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df['StockCode'] = df['StockCode'].apply(lambda x: x[:5] if len(x) > 4 else x)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country
# 0   29-Nov-16       2.55     17850.0  United Kingdom
# 1   29-Nov-16       3.39     17850.0  United Kingdom
# 2   29-Nov-16       2.75     17850.0  United Kingdom
# 3   29-Nov-16       3.39     17850.0  United Kingdom
# 4   29-Nov-16       3.39     17850.0  United Kingdom

# %%
df['InvoiceNo'].nunique()
# Out:
# 22190

# %%
df['StockCode'].nunique()
# Out:
# 3216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401603 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401603 non-null  object
#  1   StockCode    401603 non-null  object
#  2   Description  401603 non-null  object
#  3   Quantity     401603 non-null  int64
#  4   InvoiceDate  401603 non-null  object
#  5   UnitPrice    401603 non-null  float64
#  6   CustomerID   401603 non-null  float64
#  7   Country      401603 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 27.6+ MB

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'])
df['Year'] = pd.to_datetime(df['InvoiceDate']).dt.year
df['Month'] = pd.to_datetime(df['InvoiceDate']).dt.month
df['Day'] = pd.to_datetime(df['InvoiceDate']).dt.isocalendar().day

df.sample(5)
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 533263    581021     23293  SET OF 12 FAIRY CAKE BAKING CASES         8
# 325726    565453     23344          JUMBO BAG 50'S CHRISTMAS         10
# 110998    545706     82482  WOODEN PICTURE FRAME WHITE FINISH         6
# 235365    557636     21269       ANTIQUE CREAM CUTLERY SHELF          1
# 299562    563110     23202             JUMBO BAG VINTAGE LEAF        10
#
#        InvoiceDate  UnitPrice  CustomerID         Country  Year  Month  Day
# 533263  2017-12-05       0.83     14769.0  United Kingdom  2017     12    2
# 325726  2017-09-02       2.08     15136.0  United Kingdom  2017      9    6
# 110998  2017-03-05       2.55     12712.0         Germany  2017      3    7
# 235365  2017-06-19       8.50     17841.0  United Kingdom  2017      6    1
# 299562  2017-08-10       2.08     14849.0  United Kingdom  2017      8    4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401603 entries, 0 to 541908
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401603 non-null  object
#  1   StockCode    401603 non-null  object
#  2   Description  401603 non-null  object
#  3   Quantity     401603 non-null  int64
#  4   InvoiceDate  401603 non-null  datetime64[ns]
#  5   UnitPrice    401603 non-null  float64
#  6   CustomerID   401603 non-null  float64
#  7   Country      401603 non-null  object
#  8   Year         401603 non-null  int64
#  9   Month        401603 non-null  int64
#  10  Day          401603 non-null  UInt32
# dtypes: UInt32(1), datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 35.6+ MB

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.distplot(df['Quantity'], kde=False, color='blue')
plt.title('Distribution of Quantity')
plt.subplot(1,2,2)
sns.distplot(df['UnitPrice'], kde=False, color='red')
plt.title('Distribution of Unit Price')
plt.show()
# Out:
# C:\Users\Karna Patel\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['Country'], palette='inferno')
plt.title('Number of Orders by Country')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Karna Patel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df['TotalAmount'] = df['Quantity'] * df['UnitPrice']

plt.figure(figsize=(12,6))
sns.scatterplot(df['InvoiceDate'], df['TotalAmount'], color='blue', alpha=0.5)
plt.title('Total Amount Spent over Time')
plt.show()
# Out:
# C:\Users\Karna Patel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as pyo
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool
monthly_revenue = df.set_index('InvoiceDate').groupby(pd.Grouper(freq='M'))['TotalAmount'].sum().reset_index()
monthly_revenue['InvoiceDate'] = monthly_revenue['InvoiceDate'].dt.strftime('%Y-%m')
fig = px.line(monthly_revenue, x='InvoiceDate', y='TotalAmount', title='Monthly Revenue')
fig.show()
# Out:
# <div>                            <div id="1b320878-3a3a-4bf3-ba67-abea835376ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b320878-3a3a-4bf3-ba67-abea835376ef")) {                    Plotly.newPlot(                        "1b320878-3a3a-4bf3-ba67-abea835376ef",                        [{"hovertemplate": "InvoiceDate=%{x}<br>TotalAmount=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2016-11", "2016-12", "2017-01", "2017-02", "2017-03", "2017-04", "2017-05", "2017-06", "2017-07", "2017-08", "2017-09", "2017-10", "2017-11", "2017-12"], "xaxis": "x", "y": [95256.39, 493216.21, 706684.14, 455987.67, 591782.67, 4927
# ...

# %%
corr_matrix = df.corr()

# Create a heatmap using seaborn
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Group the data by month and calculate the total sales
monthly_sales = df.groupby(pd.Grouper(key='InvoiceDate', freq='M'))['TotalAmount'].sum().reset_index()

# Plot a line chart
plt.figure(figsize=(12,6))
sns.lineplot(x='InvoiceDate', y='TotalAmount', data=monthly_sales)
plt.title('Monthly Sales Trend')
plt.show()

# %%
# Group the data by product category and calculate the total sales
sales_by_category = df.groupby(['Description'])['TotalAmount'].sum().reset_index()

# Sort the data in descending order
sales_by_category = sales_by_category.sort_values(by='TotalAmount', ascending=False).head(25)

# Plot a horizontal bar chart
plt.figure(figsize=(12,6))
sns.barplot(x='TotalAmount', y='Description', data=sales_by_category)
plt.title('Sales by Product Category')
plt.show()

# %%
# Group the data by CustomerID and calculate the total sales and number of orders
customer_data = df.groupby(['CustomerID']).agg({'TotalAmount': 'sum', 'InvoiceNo': 'count'}).reset_index()

# Rename the columns
customer_data = customer_data.rename(columns={'TotalAmount': 'Revenue', 'InvoiceNo': 'Orders'})

# Plot a scatter plot
plt.figure(figsize=(12,6))
sns.scatterplot(x='Orders', y='Revenue', data=customer_data)
# Out:
# <AxesSubplot:xlabel='Orders', ylabel='Revenue'>

# %%
# Group the data by product and calculate the total sales
top_products = df.groupby(['Description'])['TotalAmount'].sum().reset_index()

# Sort the data in descending order
top_products = top_products.sort_values(by='TotalAmount', ascending=False).head(10)

# Get the stock codes for the top 10 products
top_products_codes = top_products['Description'].tolist()

# Filter the data to only include the top 10 products
top_products_data = df[df['Description'].isin(top_products_codes)]

# Group the data by product and month and calculate the total sales
monthly_sales_top_products = top_products_data.groupby([pd.Grouper(key='InvoiceDate', freq='M'), 'Description'])['TotalAmount'].sum().reset_index()

# Pivot the data to create a matrix
monthly_sales_top_products_pivot = monthly_sales_top_products.pivot(index='InvoiceDate', columns='Description', values='TotalAmount')

# Calculate the correlation matrix
corr_matrix = monthly_sales_top_products_pivot.corr()

# Create a heatmap using seaborn
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix for Top 10 Selling Products')
plt.show()

# %%
df = df.set_index('InvoiceDate')

# Calculate the total sales per day
sales_per_day = df.resample('D')['TotalAmount'].sum()

# Plot the time series of sales
plt.figure(figsize=(10,8))
plt.plot(sales_per_day)
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales Over Time')
plt.show()

# %%
sales_by_day = df.groupby(df.index.day_name())['TotalAmount'].sum()

# Plot the sales by day of the week
plt.figure(figsize=(10,8))
sns.barplot(x=sales_by_day.index, y=sales_by_day)
plt.xlabel('Day of the Week')
plt.ylabel('Sales')
plt.title('Sales by Day of the Week')
plt.show()

# %%
sales_by_month = df.groupby(df.index.month)['TotalAmount'].sum()

# Plot the sales by month
plt.figure(figsize=(10,8))
sns.barplot(x=sales_by_month.index, y=sales_by_month)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Sales by Month')
plt.show()

# %%
df['Year'].nunique()
# Out:
# 2

# %%
sales_by_year = df.groupby(df.index.year)['TotalAmount'].sum()

# Plot the sales by year
plt.figure(figsize=(10,8))
sns.barplot(x=sales_by_year.index, y=sales_by_year)
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('Sales by Year')
plt.show()
